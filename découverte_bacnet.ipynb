# %%
import time
import BAC0
disco1 = []
bacnet = BAC0.lite('172.21.212.141',bbmdAddress='192.168.1.101',bbmdTTL=900)
while len(disco1)<2:
    disco1 = bacnet.whois()
    print(disco1)

bacnet.disconnect()
# Out:
# 2025-08-26 13:25:42,066 - INFO    | Starting BAC0 version 20.11.21 (Lite)
# 2025-08-26 13:25:42,068 - INFO    | Use BAC0.log_level to adjust verbosity of the app.
# 2025-08-26 13:25:42,069 - INFO    | Ex. BAC0.log_level('silence') or BAC0.log_level('error')
# 2025-08-26 13:25:42,069 - INFO    | Starting TaskManager
# 2025-08-26 13:25:42,070 - INFO    | Using ip : 172.21.212.141
# 2025-08-26 13:25:42,072 - INFO    | Starting app...
# 2025-08-26 13:25:42,074 - INFO    | BAC0 started
# 2025-08-26 13:25:42,075 - INFO    | Registered as Foreign Device
# 2025-08-26 13:25:42,090 - INFO    | Update Local COV Task started
# []
# ...

# %%
bacnet = BAC0.lite('172.21.212.141',bbmdAddress='192.168.1.101',bbmdTTL=900)

with open("data_sonar.txt","w+") as f:
    for i in disco1:
        dev = BAC0.device(i[0], i[1], bacnet)
        objects = dev.points
        print(objects)
        f.write(str(objects))
    f.close()
bacnet.disconnect()

# %%
import BAC0
import json
disco1 = []

chambres = [301, 302, 306, 307, 308, 309, 310, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 863, 864, 865, 866, 867, 868, 869, 870, 871, 872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 933, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110, 2201, 2202, 2203, 2204, 2205, 2206, 2207, 2208, 2209, 2210, 2211, 2212, 2301, 2302, 2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321, 2322, 2401, 2403, 2404, 2405, 2406, 2407, 2409, 2416, 2417, 2418, 2419, 2420, 2421, 2422]
print(len(chambres))
bacnet = BAC0.lite('172.21.212.141',bbmdAddress='192.168.1.101',bbmdTTL=900)
while len(disco1)<2:
    disco1 = bacnet.whois()
    print(disco1)
room_dic = {}
with open("room_sonar.json","w+") as f:
    for i in disco1:
        if i[1] in chambres:
            room_dic[i[1]] = i[0]
    json.dump(room_dic, f, indent=4)
    f.close()
bacnet.disconnect()
print(room_dic)

# %%
import BAC0
import json
bacnet = BAC0.lite('172.21.212.141',bbmdAddress='192.168.1.101',bbmdTTL=900)
BAC0.log_level('silence')
def get_room():
    dev = BAC0.device('192.168.1.50',1000, bacnet)
    objects = dev.points
    room_json = {}
    print(len(objects))
    for i in range(0,len(objects)-5,6):
        temp = str(objects[i]).split("-")
        temp = int(temp[0].replace("MCS BACnet stack\n/TH_CO2_", ""))
        room_json[str(temp)] = [str(objects[i+1]),str(objects[i+2]),str(objects[i+3]),str(objects[i+4]),str(objects[i+5])]
        print(room_json[str(temp)])

    return room_json


r=get_room()
print(r)

# %%
import BAC0
import json
bacnet = BAC0.lite('172.21.212.141',bbmdAddress='192.168.100.1',bbmdTTL=900)
disco1 = bacnet.whois()
print(disco1)
BAC0.log_level('silence')
def get_room():
    dev = BAC0.device('192.168.101.187',1101, bacnet)
    objects = dev.points
    return objects

print(get_room())
# Out:
# 2025-08-26 13:25:15,905 - INFO    | Starting BAC0 version 20.11.21 (Lite)
# 2025-08-26 13:25:15,905 - INFO    | Use BAC0.log_level to adjust verbosity of the app.
# 2025-08-26 13:25:15,906 - INFO    | Ex. BAC0.log_level('silence') or BAC0.log_level('error')
# 2025-08-26 13:25:15,906 - INFO    | Starting TaskManager
# 2025-08-26 13:25:15,908 - INFO    | Using ip : 172.21.212.141
# 2025-08-26 13:25:15,910 - INFO    | Starting app...
# 2025-08-26 13:25:15,911 - INFO    | BAC0 started
# 2025-08-26 13:25:15,911 - INFO    | Registered as Foreign Device
# 2025-08-26 13:25:15,925 - INFO    | Update Local COV Task started
# []
# []
